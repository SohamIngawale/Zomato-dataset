# %%
import pandas as pd

# %%
df = pd.read_csv('zomato-data-.csv')
df
# Out:
#                                                name online_order book_table  \
# 0                                             Jalsa          Yes        Yes
# 1                                    Spice Elephant          Yes         No
# 2                                   San Churro Cafe          Yes         No
# 3                             Addhuri Udupi Bhojana           No         No
# 4                                     Grand Village           No         No
# 5                                   Timepass Dinner          Yes         No
# 6   Rosewood International Hotel - Bar & Restaurant           No         No
# 7                                            Onesta          Yes        Yes
# 8                                    Penthouse Cafe          Yes         No
# 9                                         Smacznego          Yes         No
# 10                                     Village Café          Yes         No
# ...

# %%
df
# Out:
#                                                name online_order book_table  \
# 0                                             Jalsa          Yes        Yes
# 1                                    Spice Elephant          Yes         No
# 2                                   San Churro Cafe          Yes         No
# 3                             Addhuri Udupi Bhojana           No         No
# 4                                     Grand Village           No         No
# 5                                   Timepass Dinner          Yes         No
# 6   Rosewood International Hotel - Bar & Restaurant           No         No
# 7                                            Onesta          Yes        Yes
# 8                                    Penthouse Cafe          Yes         No
# 9                                         Smacznego          Yes         No
# 10                                     Village Café          Yes         No
# ...

# %%
df.shape
# Out:
# (19, 7)

# %%
df.head(5)
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df.tail(5)
# Out:
#                 name online_order book_table   rate  votes  \
# 14   San Churro Cafe          Yes         No  3.8/5    918
# 15     Cafe Vivacity          Yes         No  3.8/5     90
# 16      Catch-up-ino          Yes         No  3.9/5    133
# 17  Kirthi's Biryani          Yes         No  3.8/5    144
# 18          T3H Cafe           No         No  3.9/5     93
#
#     approx_cost(for two people) listed_in(type)
# 14                          800           Cafes
# 15                          650           Cafes
# 16                          800           Cafes
# 17                          700           Cafes
# 18                          300           Cafes

# %%
df[2:5]
# Out:
#                     name online_order book_table   rate  votes  \
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df[['name','online_order','rate']]
# Out:
#                                                name online_order   rate
# 0                                             Jalsa          Yes  4.1/5
# 1                                    Spice Elephant          Yes  4.1/5
# 2                                   San Churro Cafe          Yes  3.8/5
# 3                             Addhuri Udupi Bhojana           No  3.7/5
# 4                                     Grand Village           No  3.8/5
# 5                                   Timepass Dinner          Yes  3.8/5
# 6   Rosewood International Hotel - Bar & Restaurant           No  3.6/5
# 7                                            Onesta          Yes  4.6/5
# 8                                    Penthouse Cafe          Yes  4.0/5
# 9                                         Smacznego          Yes  4.2/5
# 10                                     Village Café          Yes  4.1/5
# 11                                     Cafe Shuffle          Yes  4.2/5
# ...

# %%
df['name']
# Out:
# 0                      Jalsa
# 1             Spice Elephant
# 2            San Churro Cafe
# 3      Addhuri Udupi Bhojana
# 4              Grand Village
#                ...
# 143         Melting Melodies
# 144          New Indraprasta
# 145             Anna Kuteera
# 146                   Darbar
# 147            Vijayalakshmi
# Name: name, Length: 148, dtype: object

# %% [markdown]
# # Conditionally select data in dataframe

# %%
df
# Out:
#                                                name online_order book_table  \
# 0                                             Jalsa          Yes        Yes
# 1                                    Spice Elephant          Yes         No
# 2                                   San Churro Cafe          Yes         No
# 3                             Addhuri Udupi Bhojana           No         No
# 4                                     Grand Village           No         No
# 5                                   Timepass Dinner          Yes         No
# 6   Rosewood International Hotel - Bar & Restaurant           No         No
# 7                                            Onesta          Yes        Yes
# 8                                    Penthouse Cafe          Yes         No
# 9                                         Smacznego          Yes         No
# 10                                     Village Café          Yes         No
# ...

# %%
df.set_index('rate')
# Out:
#                                                   name online_order  \
# rate
# 4.1/5                                            Jalsa          Yes
# 4.1/5                                   Spice Elephant          Yes
# 3.8/5                                  San Churro Cafe          Yes
# 3.7/5                            Addhuri Udupi Bhojana           No
# 3.8/5                                    Grand Village           No
# 3.8/5                                  Timepass Dinner          Yes
# 3.6/5  Rosewood International Hotel - Bar & Restaurant           No
# 4.6/5                                           Onesta          Yes
# 4.0/5                                   Penthouse Cafe          Yes
# 4.2/5                                        Smacznego          Yes
# 4.1/5                                     Village Café          Yes
# 4.2/5                                     Cafe Shuffle          Yes
# 4.2/5                                 The Coffee Shack          Yes
# ...

# %%
df
# Out:
#                                                name online_order book_table  \
# 0                                             Jalsa          Yes        Yes
# 1                                    Spice Elephant          Yes         No
# 2                                   San Churro Cafe          Yes         No
# 3                             Addhuri Udupi Bhojana           No         No
# 4                                     Grand Village           No         No
# 5                                   Timepass Dinner          Yes         No
# 6   Rosewood International Hotel - Bar & Restaurant           No         No
# 7                                            Onesta          Yes        Yes
# 8                                    Penthouse Cafe          Yes         No
# 9                                         Smacznego          Yes         No
# 10                                     Village Café          Yes         No
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pip install scipy
# Out:
# ...
#    ---------------------------------------- 0.0/41.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/41.2 MB ? eta -:--:--
#    - -------------------------------------- 1.0/41.2 MB 3.1 MB/s eta 0:00:13
#    - -------------------------------------- 1.6/41.2 MB 3.0 MB/s eta 0:00:14
#    -- ------------------------------------- 2.4/41.2 MB 3.1 MB/s eta 0:00:13
#    --- ------------------------------------ 3.1/41.2 MB 3.2 MB/s eta 0:00:12
#    --- ------------------------------------ 3.9/41.2 MB 3.4 MB/s eta 0:00:12
#    ---- ----------------------------------- 4.5/41.2 MB 3.3 MB/s eta 0:00:12
#    ----- ---------------------------------- 5.5/41.2 MB 3.4 MB/s eta 0:00:11
#    ------ --------------------------------- 6.3/41.2 MB 3.5 MB/s eta 0:00:11
#    ------ --------------------------------- 7.1/41.2 MB 3.5 MB/s eta 0:00:10
#    ------- -------------------------------- 8.1/41.2 MB 3.6 MB/s eta 0:00:10
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy

# %%
plt.scatter(df.votes,df.rate)
plt.show()

# %%
plt.scatter(df.votes,df.rate)
sns.set_style("dark")
plt.show()

# %%
df
# Out:
#                                                name online_order book_table  \
# 0                                             Jalsa          Yes        Yes
# 1                                    Spice Elephant          Yes         No
# 2                                   San Churro Cafe          Yes         No
# 3                             Addhuri Udupi Bhojana           No         No
# 4                                     Grand Village           No         No
# 5                                   Timepass Dinner          Yes         No
# 6   Rosewood International Hotel - Bar & Restaurant           No         No
# 7                                            Onesta          Yes        Yes
# 8                                    Penthouse Cafe          Yes         No
# 9                                         Smacznego          Yes         No
# 10                                     Village Café          Yes         No
# ...

# %%
df = pd.read_csv("zomato-data-.csv")  
df = df.head(10)

# %%
df['rate'] = df['rate'].astype(str).str.replace('/5', '', regex=False)
df['rate'] = pd.to_numeric(df['rate'], errors='coerce')

# %%
sns.distplot(df['rate'],kde=False)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12872\3469076417.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['rate'],kde=False)
# <Axes: xlabel='rate'>

# %%
df = pd.read_csv("zomato-data-.csv")
df.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
sns.barplot(x='rate', y='votes', data=df, palette='PuRd', ci=None)
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14836\1888105541.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='rate', y='votes', data=df, palette='PuRd', ci=None)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14836\1888105541.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='rate', y='votes', data=df, palette='PuRd', ci=None)

# %%
sns.barplot(x='rate', y='votes', data=df, palette='PuRd', ci=None,orient='h')
plt.legend()
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12872\676709774.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='rate', y='votes', data=df, palette='PuRd', ci=None,orient='h')
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12872\676709774.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='rate', y='votes', data=df, palette='PuRd', ci=None,orient='h')
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12872\676709774.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import seaborn as sns

sns.jointplot(x='rate', y='votes', data=df, kind='scatter')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x="rate", y="votes", data=df)
plt.show()

# %%
sns.jointplot(x='approx_cost(for two people)',y='votes',data=df,kind='kde')
